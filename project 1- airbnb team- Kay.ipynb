# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('Airbnb_Open_Data.csv')

# %%
df1.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
df1.isnull()
# Out:
#            id   NAME  host id  host_identity_verified  host name  \
# 0       False  False    False                   False      False
# 1       False  False    False                   False      False
# 2       False  False    False                    True      False
# 3       False   True    False                   False      False
# 4       False  False    False                   False      False
# ...       ...    ...      ...                     ...        ...
# 102594  False  False    False                   False      False
# 102595  False  False    False                   False      False
# 102596  False  False    False                   False      False
# 102597  False  False    False                   False      False
# 102598  False  False    False                   False      False
#
#         neighbourhood group  neighbourhood    lat   long  country  ...  \
# 0                     False          False  False  False    False  ...
# ...

# %%
df1.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
df1.tail()
# Out:
#              id                              NAME      host id  \
# 102594  6092437        Spare room in Williamsburg  12312296767
# 102595  6092990     Best Location near Columbia U  77864383453
# 102596  6093542    Comfy, bright room in Brooklyn  69050334417
# 102597  6094094  Big Studio-One Stop from Midtown  11160591270
# 102598  6094647              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# 102594               verified         Krik            Brooklyn
# 102595            unconfirmed        Mifan           Manhattan
# 102596            unconfirmed        Megan            Brooklyn
# 102597            unconfirmed  Christopher              Queens
# 102598            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# ...

# %% [markdown]
# most visited area/city
# price variation
# tourism factors across the states
# [price/city/popularity/ratings/
#
# can do price vs popularity correlation?
# instant_bookable
# 'host_identity_verified does being verified affect bookings?
# use 'neighbourhood'to find something out. moving forward we can use geoify to get more geo data.
# does higher prices equal higher ratings?
# does higher prices
# min nights vs ratings
# neighboorhood vs price [min nights in this neighbhoorhood affect price]
#
# research question
#  we hired by airbnb,
#  why are ppl spending their money in the way that they do?
#
#  we analyze various airbnb factors to identify trends that impact customer /booking/

# %%
df1.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df1['country'].unique()
# Out:
# array(['United States', nan], dtype=object)

# %%
df1['neighbourhood']
# Out:
# 0                  Kensington
# 1                     Midtown
# 2                      Harlem
# 3                Clinton Hill
# 4                 East Harlem
#                  ...
# 102594           Williamsburg
# 102595    Morningside Heights
# 102596             Park Slope
# 102597       Long Island City
# 102598        Upper West Side
# Name: neighbourhood, Length: 102599, dtype: object

# %%
df1['neighbourhood group']
# Out:
# 0          Brooklyn
# 1         Manhattan
# 2         Manhattan
# 3          Brooklyn
# 4         Manhattan
#             ...
# 102594     Brooklyn
# 102595    Manhattan
# 102596     Brooklyn
# 102597       Queens
# 102598    Manhattan
# Name: neighbourhood group, Length: 102599, dtype: object

# %%
df1['country code']
# Out:
# 0         US
# 1         US
# 2         US
# 3         US
# 4         US
#           ..
# 102594    US
# 102595    US
# 102596    US
# 102597    US
# 102598    US
# Name: country code, Length: 102599, dtype: object

# %%
df1['last review'][1]
# Out:
# '5/21/2022'

# %%
r= df1['last review'][1:]
r
# Out:
# 1          5/21/2022
# 2                NaN
# 3           7/5/2019
# 4         11/19/2018
# 5          6/22/2019
#              ...
# 102594           NaN
# 102595      7/6/2015
# 102596           NaN
# 102597    10/11/2015
# 102598           NaN
# Name: last review, Length: 102598, dtype: object

# %%
s=pd.Series(r)
s.str.split(pat = "/")
# Out:
# 1          [5, 21, 2022]
# 2                    NaN
# 3           [7, 5, 2019]
# 4         [11, 19, 2018]
# 5          [6, 22, 2019]
#                ...
# 102594               NaN
# 102595      [7, 6, 2015]
# 102596               NaN
# 102597    [10, 11, 2015]
# 102598               NaN
# Name: last review, Length: 102598, dtype: object

# %%
s=pd.Series(r).str.split(pat = "/")
s[2]
# Out:
# nan

# %%
s
# Out:
# 1          [5, 21, 2022]
# 2                    NaN
# 3           [7, 5, 2019]
# 4         [11, 19, 2018]
# 5          [6, 22, 2019]
#                ...
# 102594               NaN
# 102595      [7, 6, 2015]
# 102596               NaN
# 102597    [10, 11, 2015]
# 102598               NaN
# Name: last review, Length: 102598, dtype: object

# %%
s[1][2]
# Out:
# '2022'

# %%
s[1]
# Out:
# ['5', '21', '2022']

# %%
s.dropna()
s
# Out:
# 1          [5, 21, 2022]
# 2                    NaN
# 3           [7, 5, 2019]
# 4         [11, 19, 2018]
# 5          [6, 22, 2019]
#                ...
# 102594               NaN
# 102595      [7, 6, 2015]
# 102596               NaN
# 102597    [10, 11, 2015]
# 102598               NaN
# Name: last review, Length: 102598, dtype: object

# %%
df1[df1.columns[0:14]].head(2)
# Out:
#         id                                NAME      host id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
# 1  1002102               Skylit Midtown Castle  52335172823
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
#
#         lat      long        country country code instant_bookable  \
# 0  40.64749 -73.97237  United States           US            False
# 1  40.75362 -73.98377  United States           US            False
#
#   cancellation_policy        room type
# 0              strict     Private room
# 1            moderate  Entire home/apt

# %%
df1.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
df1[df1.columns[14:]].head(2)
# Out:
#    Construction year  price service fee  minimum nights  number of reviews  \
# 0             2020.0  $966        $193             10.0                9.0
# 1             2007.0  $142         $28             30.0               45.0
#
#   last review  reviews per month  review rate number  \
# 0  10/19/2021               0.21                 4.0
# 1   5/21/2022               0.38                 4.0
#
#    calculated host listings count  availability 365  \
# 0                             6.0             286.0
# 1                             2.0             228.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN

# %%
df1[['price','NAME']]
# Out:
#           price                                              NAME
# 0         $966                 Clean & quiet apt home by the park
# 1         $142                              Skylit Midtown Castle
# 2         $620                THE VILLAGE OF HARLEM....NEW YORK !
# 3         $368                                                NaN
# 4         $204   Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594    $844                         Spare room in Williamsburg
# 102595    $837                      Best Location near Columbia U
# 102596    $988                     Comfy, bright room in Brooklyn
# 102597    $546                   Big Studio-One Stop from Midtown
# 102598  $1,032                               585 sf Luxury Studio
#
# [102599 rows x 2 columns]

# %%
df1.shape
# Out:
# (102599, 26)

# %%
df1.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
#df1.drop(['license','house_rules','country','host name','host id'],axis=1,inplace=True)
df_dropped=df1.drop(['license','house_rules','country','host name','host id', 'NAME', 'id', 'country code'],axis=1)

# %%
df1.shape,df_dropped.shape
# Out:
# ((102599, 26), (102599, 18))

# %%
df_dropped.head()
# Out:
#   host_identity_verified neighbourhood group neighbourhood       lat  \
# 0            unconfirmed            Brooklyn    Kensington  40.64749
# 1               verified           Manhattan       Midtown  40.75362
# 2                    NaN           Manhattan        Harlem  40.80902
# 3            unconfirmed            Brooklyn  Clinton Hill  40.68514
# 4               verified           Manhattan   East Harlem  40.79851
#
#        long instant_bookable cancellation_policy        room type  \
# 0 -73.97237            False              strict     Private room
# 1 -73.98377            False            moderate  Entire home/apt
# 2 -73.94190             True            flexible     Private room
# 3 -73.95976             True            moderate  Entire home/apt
# 4 -73.94399            False            moderate  Entire home/apt
#
#    Construction year  price service fee  minimum nights  number of reviews  \
# ...

# %%
df_dropped.columns
# Out:
# Index(['host_identity_verified', 'neighbourhood group', 'neighbourhood', 'lat',
#        'long', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365'],
#       dtype='object')

# %%
df_dropped.set_index('neighbourhood group')
#setting index to neighbourhood group for EDA puprposes. 
#can now find corr between neighbourhood group vs others
# Out:
#                     host_identity_verified        neighbourhood       lat  \
# neighbourhood group
# Brooklyn                       unconfirmed           Kensington  40.64749
# Manhattan                         verified              Midtown  40.75362
# Manhattan                              NaN               Harlem  40.80902
# Brooklyn                       unconfirmed         Clinton Hill  40.68514
# Manhattan                         verified          East Harlem  40.79851
# ...                                    ...                  ...       ...
# Brooklyn                          verified         Williamsburg  40.70862
# Manhattan                      unconfirmed  Morningside Heights  40.80460
# Brooklyn                       unconfirmed           Park Slope  40.67505
# Queens                         unconfirmed     Long Island City  40.74989
# Manhattan                      unconfirmed      Upper West Side  40.76807
#
# ...

# %%
df_dropped['last review'].isnull()
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 102594     True
# 102595    False
# 102596     True
# 102597    False
# 102598     True
# Name: last review, Length: 102599, dtype: bool

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import seaborn as sns

# %%
df_dropped['last review'].dtype
# Out:
# dtype('O')

# %%
t= df_dropped['last review'].isnull()
t
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 102594     True
# 102595    False
# 102596     True
# 102597    False
# 102598     True
# Name: last review, Length: 102599, dtype: bool

# %%
sum(bool(x) for x in t)
# Out:
# 15893

# %%
def count(t):
    c=0
    for i in t:
        if(i==True):
            c+=1
    return c

print(count(t))
# Out:
# 15893

# %% [markdown]
# so there are 15,893 nan values in the last review col. that only accounts for 15% of the data we have. We can safely drop these nan values and not have it affect our findings.

# %%
df_dropped['last review']
# Out:
# 0         10/19/2021
# 1          5/21/2022
# 2                NaN
# 3           7/5/2019
# 4         11/19/2018
#              ...
# 102594           NaN
# 102595      7/6/2015
# 102596           NaN
# 102597    10/11/2015
# 102598           NaN
# Name: last review, Length: 102599, dtype: object

# %%
df_dropped['last review'].dropna()
# Out:
# 0         10/19/2021
# 1          5/21/2022
# 3           7/5/2019
# 4         11/19/2018
# 5          6/22/2019
#              ...
# 102588     6/29/2019
# 102591      1/4/2019
# 102593      9/6/2015
# 102595      7/6/2015
# 102597    10/11/2015
# Name: last review, Length: 86706, dtype: object

# %%
df_dropped[['Month', 'Day', 'Last Review Year']] = df_dropped['last review'].str.extract(r'(\d+)/(\d+)/(\d+)')

# %%
df_dropped.head()
# Out:
#   host_identity_verified neighbourhood group neighbourhood       lat  \
# 0            unconfirmed            Brooklyn    Kensington  40.64749
# 1               verified           Manhattan       Midtown  40.75362
# 2                    NaN           Manhattan        Harlem  40.80902
# 3            unconfirmed            Brooklyn  Clinton Hill  40.68514
# 4               verified           Manhattan   East Harlem  40.79851
#
#        long instant_bookable cancellation_policy        room type  \
# 0 -73.97237            False              strict     Private room
# 1 -73.98377            False            moderate  Entire home/apt
# 2 -73.94190             True            flexible     Private room
# 3 -73.95976             True            moderate  Entire home/apt
# 4 -73.94399            False            moderate  Entire home/apt
#
#    Construction year  price  ... minimum nights  number of reviews  \
# 0             2020.0  $966   ...           10.0                9.0
# ...

# %%
df_dropped2=df_dropped.drop(['Month', 'Day', 'last review'], axis=1)

# %%
df_dropped2.head()
# Out:
#   host_identity_verified neighbourhood group neighbourhood       lat  \
# 0            unconfirmed            Brooklyn    Kensington  40.64749
# 1               verified           Manhattan       Midtown  40.75362
# 2                    NaN           Manhattan        Harlem  40.80902
# 3            unconfirmed            Brooklyn  Clinton Hill  40.68514
# 4               verified           Manhattan   East Harlem  40.79851
#
#        long instant_bookable cancellation_policy        room type  \
# 0 -73.97237            False              strict     Private room
# 1 -73.98377            False            moderate  Entire home/apt
# 2 -73.94190             True            flexible     Private room
# 3 -73.95976             True            moderate  Entire home/apt
# 4 -73.94399            False            moderate  Entire home/apt
#
#    Construction year  price service fee  minimum nights  number of reviews  \
# ...

# %%
df_dropped2.columns
# Out:
# Index(['host_identity_verified', 'neighbourhood group', 'neighbourhood', 'lat',
#        'long', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'reviews per month', 'review rate number',
#        'calculated host listings count', 'availability 365',
#        'Last Review Year'],
#       dtype='object')

# %%
df_dropped3 = df_dropped2.dropna()
df_dropped3.head()
# Out:
#   host_identity_verified neighbourhood group neighbourhood       lat  \
# 0            unconfirmed            Brooklyn    Kensington  40.64749
# 1               verified           Manhattan       Midtown  40.75362
# 3            unconfirmed            Brooklyn  Clinton Hill  40.68514
# 4               verified           Manhattan   East Harlem  40.79851
# 5               verified           Manhattan   Murray Hill  40.74767
#
#        long instant_bookable cancellation_policy        room type  \
# 0 -73.97237            False              strict     Private room
# 1 -73.98377            False            moderate  Entire home/apt
# 3 -73.95976             True            moderate  Entire home/apt
# 4 -73.94399            False            moderate  Entire home/apt
# 5 -73.97500             True            flexible  Entire home/apt
#
#    Construction year  price service fee  minimum nights  number of reviews  \
# ...

# %%
#he wants hues 
#how to color code the bars to rep

# %%
df_dropped3.columns
# Out:
# Index(['host_identity_verified', 'neighbourhood group', 'neighbourhood', 'lat',
#        'long', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'reviews per month', 'review rate number',
#        'calculated host listings count', 'availability 365',
#        'Last Review Year'],
#       dtype='object')

# %%
data=df_dropped3[['room type', 'cancellation_policy', 'instant_bookable','neighbourhood group','price','Construction year','review rate number','service fee', 'minimum nights','number of reviews','reviews per month','calculated host listings count', 'Last Review Year', 'availability 365']]

# %%
data['price']=data['price'].str.replace('$','').str.replace(',','').str.strip().astype(float)

# %%
data['service fee']=data['service fee'].str.replace('$','').str.replace(',','').str.strip().astype(float)

# %%
data.columns
# Out:
# Index(['room type', 'cancellation_policy', 'instant_bookable',
#        'neighbourhood group', 'price', 'Construction year',
#        'review rate number', 'service fee', 'minimum nights',
#        'number of reviews', 'reviews per month',
#        'calculated host listings count', 'Last Review Year',
#        'availability 365'],
#       dtype='object')

# %%
data['neighbourhood group'].replace('brookln','Brooklyn',inplace=True)
#replace the row name from brookln to brooklyn

# %%
#Average Price Per Neighbourhood Group

data.groupby(['neighbourhood group'])['price'].mean().plot(kind='bar', color='darkturquoise')
plt.xlabel("Neighbourhood Group")
plt.ylabel("Average Price")
plt.xlim(-1,5)
plt.ylim(0,710)
plt.title("Average Price Per Neighbourhood Group")

plt.show()

# %%
data.columns
# Out:
# Index(['room type', 'cancellation_policy', 'instant_bookable',
#        'neighbourhood group', 'price', 'Construction year',
#        'review rate number', 'service fee', 'minimum nights',
#        'number of reviews', 'reviews per month',
#        'calculated host listings count', 'Last Review Year',
#        'availability 365'],
#       dtype='object')

# %% [markdown]
# create heatmap/corr plots to see relationships
# NTH: no need for a linear reg , he just wants us to explore [price vs [rate/reviews]
# Kaylyn: to do the research questions

# %%
#Review Rate Number vs. Price

plt.scatter(data['review rate number'],data['price'], color='deepskyblue')
plt.xlabel("Review Rate Number")
plt.ylabel("Price of Listing")
plt.xlim(0.5,5.5)
plt.ylim(0,1400)
plt.title("Review Rate Number vs. Price")

plt.show()

# %%
plt.scatter(data['number of reviews'],data['price'], color='powderblue')
plt.xlabel("Number of Reviews")
plt.ylabel("Price")
plt.xlim(0,1400)
plt.title("Number of Reviews vs. Price")

plt.show()

# %%
data.groupby(['Construction year'])['price'].mean().plot()
# Out:
# <Axes: xlabel='Construction year'>

# %%
#contruction year vs. price 

fig1, ax1 = plt.subplots()
con_by_price = data.groupby(['Construction year']).counts()

plt.scatter(con_by_price['Construction year'],con_by_price['price'])
plt.xlabel('Construction year')
plt.ylabel('Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 4
#       1 #contruction year vs. price
#       3 fig1, ax1 = plt.subplots()
# ----> 4 con_by_price = data.groupby(['Construction year']).counts()
#       6 plt.scatter(con_by_price['Construction year'],con_by_price['price'])
#       7 plt.xlabel('Construction year')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'counts'

# %%
data.head()
# Out:
#          room type cancellation_policy instant_bookable neighbourhood group  \
# 0     Private room              strict            False            Brooklyn
# 1  Entire home/apt            moderate            False           Manhattan
# 3  Entire home/apt            moderate             True            Brooklyn
# 4  Entire home/apt            moderate            False           Manhattan
# 5  Entire home/apt            flexible             True           Manhattan
#
#    price  Construction year  review rate number  service fee  minimum nights  \
# 0  966.0             2020.0                 4.0        193.0            10.0
# 1  142.0             2007.0                 4.0         28.0            30.0
# 3  368.0             2005.0                 4.0         74.0            30.0
# 4  204.0             2009.0                 3.0         41.0            10.0
# 5  577.0             2013.0                 3.0        115.0             3.0
#
# ...

# %%
#room type comparison 
colors = ["lightskyblue", "lightcoral", "lemonchiffon", "blueviolet"]
data['room type'].value_counts().plot(kind='pie',xlabel='X Axis', autopct= "%1.1f%%", colors=colors)
plt.title("Room Type Comparison")

#how can I zoom out a little bit to make the 'Hotel Room' area more visible?
# Out:
# Text(0.5, 1.0, 'Room Type Comparison')

# %%
#review number vs. price  

plt.scatter(data['room type'],data['number of reviews'], color='blue')
plt.xlabel("Room Type")
plt.ylabel("Number of Reviews")
plt.xlim(-1,4)
plt.ylim(0,1250)
plt.title("Room Type vs Number of Reviews")

plt.show()

#im thinking this doesn't make sense. Line chart?

# %%
#data.g(['room type'])['number of reviews'].plot(kind='line')
plt.plot(data['room type'], data['number of reviews'])

#why does it look like this..

# %%
#Cancellation policies visualisation 

data['cancellation_policy'].value_counts().plot(kind='bar',xlabel='X Axis', color='mediumpurple')
plt.xlabel("Cancellation Policy")
plt.ylabel("Number of Listings")
plt.ylim(0,35000)
plt.xlim(-1,3)
plt.title("Cancellation Policy")

plt.show()

# %%
#minimum nights vs price
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 3
#       1 #minimum nights vs price
# ----> 3 gender_versus = clean_number_mice["Sex"].value_counts()
#       4 gender_versus.plot(kind="pie", autopct= "%1.1f%%")
#       6 plt.show()
#
# NameError: name 'clean_number_mice' is not defined

# %%
cp_map={'moderate':1,
        'strict':2,
        'felxible':3
}

# %%
data['cancellation_policy'].astype('category').cat.codes
# Out:
# 0         2
# 1         1
# 3         1
# 4         1
# 5         0
#          ..
# 102588    0
# 102591    2
# 102593    2
# 102595    1
# 102597    2
# Length: 84798, dtype: int8

# %%
data['cancellation_policy1']=data['cancellation_policy'].map(cp_map)
data.head()
# Out:
#          room type cancellation_policy instant_bookable neighbourhood group  \
# 0     Private room              strict            False            Brooklyn
# 1  Entire home/apt            moderate            False           Manhattan
# 3  Entire home/apt            moderate             True            Brooklyn
# 4  Entire home/apt            moderate            False           Manhattan
# 5  Entire home/apt            flexible             True           Manhattan
#
#    price  Construction year  review rate number  service fee  minimum nights  \
# 0  966.0             2020.0                 4.0        193.0            10.0
# 1  142.0             2007.0                 4.0         28.0            30.0
# 3  368.0             2005.0                 4.0         74.0            30.0
# 4  204.0             2009.0                 3.0         41.0            10.0
# 5  577.0             2013.0                 3.0        115.0             3.0
#
# ...

# %%
df_dropped3['instant_bookable'].dtype
# Out:
# dtype('O')

# %%
df_dropped3['cancellation_policy'].dtype
# Out:
# dtype('O')

# %%
df3= pd.get_dummies(df_dropped3, columns=['room type', 'cancellation_policy', 'instant_bookable'])
#trying to figure out how to change categorical data into numerical data for EDA

# %%
df3.head()
# Out:
#   host_identity_verified neighbourhood group neighbourhood       lat  \
# 0            unconfirmed            Brooklyn    Kensington  40.64749
# 1               verified           Manhattan       Midtown  40.75362
# 3            unconfirmed            Brooklyn  Clinton Hill  40.68514
# 4               verified           Manhattan   East Harlem  40.79851
# 5               verified           Manhattan   Murray Hill  40.74767
#
#        long  Construction year  price service fee  minimum nights  \
# 0 -73.97237             2020.0  $966        $193             10.0
# 1 -73.98377             2007.0  $142         $28             30.0
# 3 -73.95976             2005.0  $368         $74             30.0
# 4 -73.94399             2009.0  $204         $41             10.0
# 5 -73.97500             2013.0  $577        $115              3.0
#
#    number of reviews  ...  Last Review Year  room type_Entire home/apt  \
# 0                9.0  ...              2021                          0
# ...

# %% [markdown]
# the above is  one hot encoding method. It takes the values in each col [room type, cancellation policy, and instant bookable] and turns it into a column.
# The new column has a one if in the original dataframe, there was a value of that specifc category in the column.
# to break it down further: room type had values entire home/apt, hotel room, private room, and shared room. With one hot encoding it takes the room column, splits it into four columns of zeros and ones. The four new columns are named after the
# values in room type. The new columns have a one if that value was in the room type column originally.
# Purpose: so we can see if there is any correlation between the different room types/cancellation policy/insta bookable and bookings

# %%
df3.shape
# Out:
# (84798, 24)

# %%
df3.rename(columns={'room type_Entire home/apt': 'Entire Home', 'room type_Private room': 'Private Room', 'room type_Shared room': 'Shared Room', 'room type_Hotel room': 'Hotel Room'}, inplace=True)
df3.head()
# Out:
#   host_identity_verified neighbourhood group neighbourhood       lat  \
# 0            unconfirmed            Brooklyn    Kensington  40.64749
# 1               verified           Manhattan       Midtown  40.75362
# 3            unconfirmed            Brooklyn  Clinton Hill  40.68514
# 4               verified           Manhattan   East Harlem  40.79851
# 5               verified           Manhattan   Murray Hill  40.74767
#
#        long  Construction year  price service fee  minimum nights  \
# 0 -73.97237             2020.0  $966        $193             10.0
# 1 -73.98377             2007.0  $142         $28             30.0
# 3 -73.95976             2005.0  $368         $74             30.0
# 4 -73.94399             2009.0  $204         $41             10.0
# 5 -73.97500             2013.0  $577        $115              3.0
#
#    number of reviews  ...  Last Review Year  Entire Home  Hotel Room  \
# 0                9.0  ...              2021            0           0
# ...

# %%
#df3.drop(["neighbourhood"]["brookln"], inplace = True)
#df3.head()

#drop "brookln"

#grouped_neighbourhood_df = grouped_neighbourhood_df_raw.drop(["brookln"], inplace = True)
#grouped_neighbourhood_df

# %%
grouped_neighbourhood_df = df_dropped3.groupby(["neighbourhood group", "neighbourhood"])

neighbourhood_totals_df_count = grouped_neighbourhood_df.count()
neighbourhood_totals_df_count
# Out:
#                                    host_identity_verified  lat  long  \
# neighbourhood group neighbourhood
# Bronx               Allerton                           86   86    86
#                     Baychester                         27   27    27
#                     Belmont                            39   39    39
#                     Bronxdale                          44   44    44
#                     Castle Hill                         8    8     8
# ...                                                   ...  ...   ...
# Staten Island       West Brighton                      54   54    54
#                     Westerleigh                         5    5     5
#                     Willowbrook                         3    3     3
#                     Woodrow                             1    1     1
# brookln             South Slope                         1    1     1
#
#                                    instant_bookable  cancellation_policy  \
# ...

# %%
#neighbourhoods_list = [["Brooklyn", "Bronx", "Staten Island", "Manhattan", "Queens"]]

#neighbourhoods_df = pd.DataFrame(neighbourhoods_list, 'col')
#neighbourhoods_df

# %%
grouped_neighbourhood_df.head()
# Out:
#       host_identity_verified neighbourhood group neighbourhood       lat  \
# 0                unconfirmed            Brooklyn    Kensington  40.64749
# 1                   verified           Manhattan       Midtown  40.75362
# 3                unconfirmed            Brooklyn  Clinton Hill  40.68514
# 4                   verified           Manhattan   East Harlem  40.79851
# 5                   verified           Manhattan   Murray Hill  40.74767
# ...                      ...                 ...           ...       ...
# 92148               verified       Staten Island   Westerleigh  40.61422
# 92672               verified       Staten Island   Bull's Head  40.60295
# 96195               verified       Staten Island     Rossville  40.54790
# 97095            unconfirmed       Staten Island   Willowbrook  40.59886
# 99817            unconfirmed       Staten Island   Eltingville  40.54106
#
#            long instant_bookable cancellation_policy        room type  \
# ...

# %%
neighbourhood_totals_df_count.columns
# Out:
# Index(['host_identity_verified', 'lat', 'long', 'instant_bookable',
#        'cancellation_policy', 'room type', 'Construction year', 'price',
#        'service fee', 'minimum nights', 'number of reviews',
#        'reviews per month', 'review rate number',
#        'calculated host listings count', 'availability 365',
#        'Last Review Year'],
#       dtype='object')

# %%
#clean neighbourhood totals df


neighbourhood_totals_df_cleaned = neighbourhood_totals_df[["instant_bookable", "cancellation_policy", "room type", "Construction year", 
                           "price", "service fee", "minimum nights", 'number of reviews', 'last review',
       'reviews per month', 'review rate number',
       'calculated host listings count', 'availability 365']]
neighbourhood_totals_df_cleaned.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 4
#       1 #clean neighbourhood totals df
# ----> 4 neighbourhood_totals_df_cleaned = neighbourhood_totals_df[["instant_bookable", "cancellation_policy", "room type", "Construction year",
#       5                            "price", "service fee", "minimum nights", 'number of reviews', 'last review',
#       6        'reviews per month', 'review rate number',
#       7        'calculated host listings count', 'availability 365']]
#       8 neighbourhood_totals_df_cleaned.head()
#
# NameError: name 'neighbourhood_totals_df' is not defined

# %%
#construction year by neighbourhood group (NG) summary stats

df_construction_year_ng_mean = df3.groupby('neighbourhood group')['Construction year'].mean()
df_construction_year_ng_median = df3.groupby('neighbourhood group')['Construction year'].median()
df_construction_year_ng_var = df3.groupby('neighbourhood group')['Construction year'].var()
df_construction_year_ng_std = df3.groupby('neighbourhood group')['Construction year'].std()
df_construction_year_ng_sem = df3.groupby('neighbourhood group')['Construction year'].sem()
df_construction_year_ng_max = df3.groupby('neighbourhood group')['Construction year'].max()
df_construction_year_ng_min = df3.groupby('neighbourhood group')['Construction year'].min()

df_construction_year_summary_ng = pd.DataFrame({"Construction Year Mean": df_construction_year_ng_mean,
                                            "Construction Year Median": df_construction_year_ng_median,
                                            "Construction Year Variance": df_construction_year_ng_var,
                                            "Construction Year Std Dev": df_construction_year_ng_std,
                                            "Construction Year SEM": df_construction_year_ng_sem,
                                            "Construction Year Max": df_construction_year_ng_max,
                                            "Construction Year Min": df_construction_year_ng_min})

df_construction_year_summary_ng
# Out:
#                      Construction Year Mean  Construction Year Median  \
# neighbourhood group
# Bronx                           2012.498702                    2012.0
# Brooklyn                        2012.511409                    2013.0
# Manhattan                       2012.487485                    2012.0
# Queens                          2012.460218                    2012.0
# Staten Island                   2011.768862                    2011.0
# brookln                         2010.000000                    2010.0
#
#                      Construction Year Variance  Construction Year Std Dev  \
# neighbourhood group
# Bronx                                 34.373862                   5.862923
# Brooklyn                              33.145421                   5.757206
# Manhattan                             32.878289                   5.733959
# Queens                                34.023267                   5.832947
# ...

# %%
#construction year by neighbourhood (N) summary stats

df_construction_year_n_mean = df3.groupby('neighbourhood')['Construction year'].mean()
df_construction_year_n_median = df3.groupby('neighbourhood')['Construction year'].median()
df_construction_year_n_var = df3.groupby('neighbourhood')['Construction year'].var()
df_construction_year_n_std = df3.groupby('neighbourhood')['Construction year'].std()
df_construction_year_n_sem = df3.groupby('neighbourhood')['Construction year'].sem()
df_construction_year_n_max = df3.groupby('neighbourhood')['Construction year'].max()
df_construction_year_n_min = df3.groupby('neighbourhood')['Construction year'].min()


df_construction_year_summary_n = pd.DataFrame({"Construction Year Mean": df_construction_year_n_mean,
                                            "Construction Year Median": df_construction_year_n_median,
                                            "Construction Year Variance": df_construction_year_n_var,
                                            "Construction Year Std Dev": df_construction_year_n_std,
                                            "Construction Year SEM": df_construction_year_n_sem,
                                            "Construction Year Min": df_construction_year_n_min,
                                            "Construction Year Max": df_construction_year_n_max})

df_construction_year_summary_n
# Out:
#                  Construction Year Mean  Construction Year Median  \
# neighbourhood
# Allerton                    2012.209302                    2012.0
# Arden Heights               2008.555556                    2008.0
# Arrochar                    2010.897959                    2010.0
# Arverne                     2012.191176                    2012.0
# Astoria                     2012.507106                    2012.0
# ...                                 ...                       ...
# Windsor Terrace             2012.645756                    2013.0
# Woodhaven                   2010.993750                    2010.0
# Woodlawn                    2012.285714                    2010.0
# Woodrow                     2010.000000                    2010.0
# Woodside                    2012.502075                    2013.0
#
#                  Construction Year Variance  Construction Year Std Dev  \
# neighbourhood
# ...

# %%
#comparing avilability of entire house vs private room based on area

ng_df = df3.set_index(["neighbourhood group"])
ng_df
# Out:
#                     host_identity_verified        neighbourhood       lat  \
# neighbourhood group
# Brooklyn                       unconfirmed           Kensington  40.64749
# Manhattan                         verified              Midtown  40.75362
# Brooklyn                       unconfirmed         Clinton Hill  40.68514
# Manhattan                         verified          East Harlem  40.79851
# Manhattan                         verified          Murray Hill  40.74767
# ...                                    ...                  ...       ...
# Manhattan                      unconfirmed    Flatiron District  40.74068
# Manhattan                         verified      Upper West Side  40.77408
# Manhattan                         verified         East Village  40.72826
# Manhattan                      unconfirmed  Morningside Heights  40.80460
# Queens                         unconfirmed     Long Island City  40.74989
#
# ...

# %%
#make dataframe for entire home vs private room vs shared room

ng_private_shared = ng_df[["Entire Home", "Private Room", "Shared Room"]]
ng_private_shared
# Out:
#                      Entire Home  Private Room  Shared Room
# neighbourhood group
# Brooklyn                       0             1            0
# Manhattan                      1             0            0
# Brooklyn                       1             0            0
# Manhattan                      1             0            0
# Manhattan                      1             0            0
# ...                          ...           ...          ...
# Manhattan                      1             0            0
# Manhattan                      1             0            0
# Manhattan                      0             1            0
# Manhattan                      0             1            0
# Queens                         1             0            0
#
# [84798 rows x 3 columns]

# %%
#entire home count, want to split by neighbourhood group

entire_home_df = ng_private_shared["Entire Home"].count()
entire_home_df
# Out:
# 84798

# %%
dff= ng_private_shared.groupby(["neighbourhood group"])
dff

# %%
#impact of precence of service fee on price based on area

# %%
#does minimum number of nights for booking impact price? and by area

# %%
#construction year vs price depending on area

# %%
#cancellation policy vs area vs room type

# %%
#number of reviews vs area (more reviews = more popular?)

# %%
#number of reviews vs area

# %%
#how does price impact service fee?

# %%
#Review rating vs area

# %%
#Instant booking vs availability 365
